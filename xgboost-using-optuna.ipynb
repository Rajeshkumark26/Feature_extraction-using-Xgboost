# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading https://files.pythonhosted.org/packages/6c/32/b8de89bd281c9799365a374daa3f66b94f61363be24a8647a38aa5498cfb/optuna-1.2.0.tar.gz (146kB)
#      |████████████████████████████████| 153kB 3.3MB/s
# Collecting alembic
#   Downloading https://files.pythonhosted.org/packages/e0/e9/359dbb77c35c419df0aedeb1d53e71e7e3f438ff64a8fdb048c907404de3/alembic-1.4.1.tar.gz (1.1MB)
#      |████████████████████████████████| 1.1MB 10.3MB/s
# Collecting cliff
#   Downloading https://files.pythonhosted.org/packages/90/e4/624f02aa2fcbf6efcd9d6bf90f92836a2ae46bc4376a824e317d10506fc8/cliff-3.0.0-py3-none-any.whl (79kB)
#      |████████████████████████████████| 81kB 7.8MB/s
# Collecting colorlog
#   Downloading https://files.pythonhosted.org/packages/00/0d/22c73c2eccb21dd3498df7d22c0b1d4a30f5a5fb3feb64e1ce06bc247747/colorlog-4.1.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from optuna) (1.17.5)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.3.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from optuna) (4.28.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from optuna) (0.14.1)
# Collecting Mako
#   Downloading https://files.pythonhosted.org/packages/50/78/f6ade1e18aebda570eed33b7c534378d9659351cadce2fcbc7b31be5f615/Mako-1.1.2-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 6.8MB/s
# Collecting python-editor>=0.3
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (2.6.1)
# Requirement already satisfied: PrettyTable<0.8,>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (0.7.2)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/7a/db/a968fd7beb9fe06901c1841cb25c9ccb666ca1b9a19b114d1bbedf1126fc/pbr-5.4.4-py2.py3-none-any.whl (110kB)
#      |████████████████████████████████| 112kB 18.0MB/s
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (3.13)
# Collecting cmd2!=0.8.3,<0.9.0,>=0.8.0
#   Downloading https://files.pythonhosted.org/packages/e9/40/a71caa2aaff10c73612a7106e2d35f693e85b8cf6e37ab0774274bca3cf9/cmd2-0.8.9-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 6.3MB/s
# Collecting stevedore>=1.20.0
#   Downloading https://files.pythonhosted.org/packages/e6/49/a35dd566626892d577e426dbe5ea424dd7fbe10645f2c1070dcba474eca9/stevedore-1.32.0-py2.py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 5.8MB/s
# Requirement already satisfied: pyparsing>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (2.4.6)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic->optuna) (1.1.1)
# Requirement already satisfied: wcwidth; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,<0.9.0,>=0.8.0->cliff->optuna) (0.1.8)
# Collecting pyperclip
#   Downloading https://files.pythonhosted.org/packages/2d/0f/4eda562dffd085945d57c2d9a5da745cfb5228c02bc90f2c74bbac746243/pyperclip-1.7.0.tar.gz
# Building wheels for collected packages: optuna, alembic, pyperclip
#   Building wheel for optuna (setup.py) ... done
#   Created wheel for optuna: filename=optuna-1.2.0-cp36-none-any.whl size=204611 sha256=55f726829f5a1730281b3226dd99467669b0139d977a29ab2e0fc69f17e51c01
#   Stored in directory: /root/.cache/pip/wheels/74/51/a0/d51cb5716dafc9f32af6559cffe42d535d3743f4eac7c98712
#   Building wheel for alembic (setup.py) ... done
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=158154 sha256=db5e6a8780102141b27204302aa68b303a7d0eb495347306ca5badb33b976534
#   Stored in directory: /root/.cache/pip/wheels/84/07/f7/12f7370ca47a66030c2edeedcc23dec26ea0ac22dcb4c4a0f3
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.7.0-cp36-none-any.whl size=8359 sha256=a953f87202f76a7933f411caba4f2d4270d9a4867d2c6930ecdd924614ed13ab
#   Stored in directory: /root/.cache/pip/wheels/92/f0/ac/2ba2972034e98971c3654ece337ac61e546bdeb34ca960dc8c
# Successfully built optuna alembic pyperclip
# Installing collected packages: Mako, python-editor, alembic, pbr, pyperclip, cmd2, stevedore, cliff, colorlog, optuna
# Successfully installed Mako-1.1.2 alembic-1.4.1 cliff-3.0.0 cmd2-0.8.9 colorlog-4.1.0 optuna-1.2.0 pbr-5.4.4 pyperclip-1.7.0 python-editor-1.0.4 stevedore-1.32.0

# %%
import os
import numpy as np
import pandas as pd
from sklearn import preprocessing
import xgboost as xgb
import lightgbm as lgb
import optuna
import functools
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve,auc,accuracy_score,confusion_matrix,f1_score

# %%
train_transaction = pd.read_csv('../input/train_transaction.csv', index_col='TransactionID')
test_transaction = pd.read_csv('../input/test_transaction.csv', index_col='TransactionID')

train_identity = pd.read_csv('../input/train_identity.csv', index_col='TransactionID')
test_identity = pd.read_csv('../input/test_identity.csv', index_col='TransactionID')

sample_submission = pd.read_csv('../input/sample_submission.csv', index_col='TransactionID')

train = train_transaction.merge(train_identity, how='left', left_index=True, right_index=True)
test = test_transaction.merge(test_identity, how='left', left_index=True, right_index=True)

print(train.shape)
print(test.shape)

y_train = train['isFraud'].copy()
del train_transaction, train_identity, test_transaction, test_identity

# Drop target, fill in NaNs
X_train = train.drop('isFraud', axis=1)
X_test = test.copy()

del train, test

X_train = X_train.fillna(-999)
X_test = X_test.fillna(-999)

# Label Encoding
for f in X_train.columns:
    if X_train[f].dtype=='object' or X_test[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f].values) + list(X_test[f].values))
        X_train[f] = lbl.transform(list(X_train[f].values))
        X_test[f] = lbl.transform(list(X_test[f].values))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-da61338050a5> in <module>()
# ----> 1 train_transaction = pd.read_csv('../input/train_transaction.csv', index_col='TransactionID')
#       2 test_transaction = pd.read_csv('../input/test_transaction.csv', index_col='TransactionID')
#       3
#       4 train_identity = pd.read_csv('../input/train_identity.csv', index_col='TransactionID')
#       5 test_identity = pd.read_csv('../input/test_identity.csv', index_col='TransactionID')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'../input/train_transaction.csv' does not exist: b'../input/train_transaction.csv'

# %%
(X_train,X_eval,y_train,y_eval) = train_test_split(X_train,y_train,test_size=0.2,random_state=0)

# %%
def opt(X_train, y_train, X_test, y_test, trial):
    #param_list
    n_estimators = trial.suggest_int('n_estimators', 0, 1000)
    max_depth = trial.suggest_int('max_depth', 1, 20)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 20)
    #learning_rate = trial.suggest_discrete_uniform('learning_rate', 0.01, 0.1, 0.01)
    scale_pos_weight = trial.suggest_int('scale_pos_weight', 1, 100)
    subsample = trial.suggest_discrete_uniform('subsample', 0.5, 0.9, 0.1)
    colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 0.9, 0.1)

    xgboost_tuna = xgb.XGBClassifier(
        random_state=42, 
        tree_method='gpu_hist',
        n_estimators = n_estimators,
        max_depth = max_depth,
        min_child_weight = min_child_weight,
        #learning_rate = learning_rate,
        scale_pos_weight = scale_pos_weight,
        subsample = subsample,
        colsample_bytree = colsample_bytree,
    )
    xgboost_tuna.fit(X_train, y_train)
    tuna_pred_test = xgboost_tuna.predict(X_test)
    
    return (1.0 - (accuracy_score(y_test, tuna_pred_test)))

# %%
study = optuna.create_study()
study.optimize(functools.partial(opt, X_train, y_train, X_eval, y_eval), n_trials=100)
# Out:
# [I 2019-07-18 16:50:13,501] Finished trial#0 resulted in value: 0.011040742371388856. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 16:50:36,315] Finished trial#1 resulted in value: 0.2977105699867918. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 16:51:15,938] Finished trial#2 resulted in value: 0.012505503437531762. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 16:52:02,652] Finished trial#3 resulted in value: 0.030251972770684477. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 16:52:54,225] Finished trial#4 resulted in value: 0.014114200562197365. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 16:53:27,812] Finished trial#5 resulted in value: 0.047727503640735636. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 16:54:19,518] Finished trial#6 resulted in value: 0.014012598638534213. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 16:55:41,891] Finished trial#7 resulted in value: 0.011692688048227096. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 16:56:50,282] Finished trial#8 resulted in value: 0.014529075083821619. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 16:57:01,449] Finished trial#9 resulted in value: 0.092025942357842. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 16:59:30,166] Finished trial#10 resulted in value: 0.011760422664002457. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 17:02:04,660] Finished trial#11 resulted in value: 0.011760422664002457. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 17:03:44,152] Finished trial#12 resulted in value: 0.011862024587665498. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 17:04:03,651] Finished trial#13 resulted in value: 0.23378602634876555. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 17:05:38,009] Finished trial#14 resulted in value: 0.012310766417177543. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 17:06:27,422] Finished trial#15 resulted in value: 0.012776441900633317. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 17:06:53,348] Finished trial#16 resulted in value: 0.020726792427269936. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 17:08:10,912] Finished trial#17 resulted in value: 0.01317438276831373. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 17:09:44,387] Finished trial#18 resulted in value: 0.01240390151386861. Current best value is 0.011040742371388856 with parameters: {'n_estimators': 841, 'max_depth': 19, 'min_child_weight': 2, 'scale_pos_weight': 58, 'subsample': 0.6, 'colsample_bytree': 0.8}.
# [I 2019-07-18 17
 'max_depth': 12, 'min_child_weight': 1, 'scale_pos_weight': 21, 'subsample': 0.5, 'colsample_bytree': 0.5}.
# [I 2019-07-18 17:59:11,180] Finished trial#65 resulted in value: 0.01096454092864163. Current best value is 0.01096454092864163 with parameters: {'n_estimators': 962, 'max_depth': 12, 'min_child_weight': 1, 'scale_pos_weight': 12, 'subsample': 0.5, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:00:29,659] Finished trial#66 resulted in value: 0.010575066887933082. Current best value is 0.010575066887933082 with parameters: {'n_estimators': 888, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 17, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:01:46,212] Finished trial#67 resulted in value: 0.010558133233989242. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:02:36,825] Finished trial#68 resulted in value: 0.012801842381549133. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:03:48,471] Finished trial#69 resulted in value: 0.010786737562231141. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:04:50,011] Finished trial#70 resulted in value: 0.011862024587665498. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:05:42,863] Finished trial#71 resulted in value: 0.013352186134724109. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:07:01,995] Finished trial#72 resulted in value: 0.011404815931181589. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:07:35,676] Finished trial#73 resulted in value: 0.016535713076167524. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:08:56,428] Finished trial#74 resulted in value: 0.011125410641108169. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:09:52,233] Finished trial#75 resulted in value: 0.013250584211061067. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:10:32,180] Finished trial#76 resulted in value: 0.030167304500965164. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:11:51,558] Finished trial#77 resulted in value: 0.011252413045687026. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:12:33,553] Finished trial#78 resulted in value: 0.02629796457479594. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:13:38,408] Finished trial#79 resulted in value: 0.012014427473160172. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:14:40,859] Finished trial#80 resulted in value: 0.012945778440071831. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:15:37,587] Finished trial#81 resulted in value: 0.012776441900633317. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:17:00,152] Finished trial#82 resulted in value: 0.011345548142378203. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:17:37,821] Finished trial#83 resulted in value: 0.01808514241202963. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:19:26,473] Finished trial#84 resulted in value: 0.010795204389203117. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:20:50,165] Finished trial#85 resulted in value: 0.011387882277237749. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:21:49,409] Finished trial#86 resulted in value: 0.012361567379009064. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:22:33,157] Finished trial#87 resulted in value: 0.01782267077590005. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:23:10,815] Finished trial#88 resulted in value: 0.11766349442882784. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:23:19,616] Finished trial#89 resulted in value: 0.08276323365055716. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:25:04,291] Finished trial#90 resulted in value: 0.0106851356385681. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:26:45,418] Finished trial#91 resulted in value: 0.011311680834490412. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:28:22,732] Finished trial#92 resulted in value: 0.011497951027872766. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:29:35,533] Finished trial#93 resulted in value: 0.012327700071121384. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:30:51,607] Finished trial#94 resulted in value: 0.012200697666542526. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:32:05,302] Finished trial#95 resulted in value: 0.012522437091475602. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:32:54,674] Finished trial#96 resulted in value: 0.012920377959156015. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:34:05,898] Finished trial#97 resulted in value: 0.01366545873268532. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:35:42,689] Finished trial#98 resulted in value: 0.011574152470620103. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.
# [I 2019-07-18 18:36:45,059] Finished trial#99 resulted in value: 0.016417177498560642. Current best value is 0.010558133233989242 with parameters: {'n_estimators': 874, 'max_depth': 11, 'min_child_weight': 3, 'scale_pos_weight': 13, 'subsample': 0.7, 'colsample_bytree': 0.7}.

# %%
study.best_params
# Out:
# {'n_estimators': 874,
#  'max_depth': 11,
#  'min_child_weight': 3,
#  'scale_pos_weight': 13,
#  'subsample': 0.7,
#  'colsample_bytree': 0.7}

# %%
clf = xgb.XGBClassifier(tree_method='gpu_hist',**study.best_params)
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.7, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=11,
#               min_child_weight=3, missing=None, n_estimators=874, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=13, seed=None,
#               silent=None, subsample=0.7, tree_method='gpu_hist', verbosity=1)

# %%
sample_submission['isFraud'] = clf.predict_proba(X_test)[:,1]
sample_submission.to_csv('submission.csv')
